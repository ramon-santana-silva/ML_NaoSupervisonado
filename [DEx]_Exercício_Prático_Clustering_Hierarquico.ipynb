# %% [markdown]
# <a href="https://colab.research.google.com/github/ramon-santana-silva/ML_supervisonado/blob/main/%5BDEx%5D_Exerc%C3%ADcio_Pr%C3%A1tico_Clustering_Hierarquico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercicio Prático Clustering Hierarquico
#
# ## Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering
from sklearn.neighbors import NearestNeighbors
from sklearn.datasets import load_iris

# %% [markdown]
# ## Dataset

# %%
df, df['target'] = pd.DataFrame(load_iris().data,columns= load_iris().feature_names), load_iris().target

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  ...  petal width (cm)  target
# 0                  5.1               3.5  ...               0.2       0
# 1                  4.9               3.0  ...               0.2       0
# 2                  4.7               3.2  ...               0.2       0
# 3                  4.6               3.1  ...               0.2       0
# 4                  5.0               3.6  ...               0.2       0
# ..                 ...               ...  ...               ...     ...
# 145                6.7               3.0  ...               2.3       2
# 146                6.3               2.5  ...               1.9       2
# 147                6.5               3.0  ...               2.0       2
# 148                6.2               3.4  ...               2.3       2
# 149                5.9               3.0  ...               1.8       2
#
# [150 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'target'],
#       dtype='object')

# %%
FEATURES = ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
       'petal width (cm)']

# %%
agg = AgglomerativeClustering(affinity = 'euclidean', linkage = 'ward')

# %%
df['cluster_hierarquico'] = agg.fit_predict(df[FEATURES])

# %%
df.groupby('target')['cluster_hierarquico'].value_counts()
# Out:
# target  cluster_hierarquico
# 0       1                      50
# 1       0                      50
# 2       0                      50
# Name: cluster_hierarquico, dtype: int64

# %%
fig, axes = plt.subplots(1, 2, figsize=(16,8))
axes[0].scatter(df['sepal length (cm)'], df['petal length (cm)'], c=df['target'])
axes[1].scatter(df['sepal length (cm)'], df['petal length (cm)'], c=df['cluster_hierarquico'], cmap=plt.cm.Set1)
axes[0].set_title('Target', fontsize=18)
axes[1].set_title('Hierarchical', fontsize=18)
# Out:
# Text(0.5, 1.0, 'Hierarchical')

# %%
plt.figure(figsize = (20,12))
dendrogram = sch.dendrogram(sch.linkage(df[FEATURES], method  = "ward"))
plt.title('Dendrogram')
plt.xlabel('Flowers')
plt.ylabel('Euclidean distances')
plt.show()

# %%
agg = AgglomerativeClustering(3, affinity = 'euclidean', linkage = 'ward')
df['cluster_hierarquico'] = agg.fit_predict(df[FEATURES])
df.groupby('target')['cluster_hierarquico'].value_counts()
# Out:
# target  cluster_hierarquico
# 0       1                      50
# 1       0                      49
#         2                       1
# 2       2                      35
#         0                      15
# Name: cluster_hierarquico, dtype: int64

# %%
fig, axes = plt.subplots(1, 2, figsize=(16,8))
axes[0].scatter(df['sepal length (cm)'], df['petal length (cm)'], c=df['target'])
axes[1].scatter(df['sepal length (cm)'], df['petal length (cm)'], c=df['cluster_hierarquico'], cmap=plt.cm.Set1)
axes[0].set_title('Target', fontsize=18)
axes[1].set_title('Hierarchical', fontsize=18)
# Out:
# Text(0.5, 1.0, 'Hierarchical')

# %%
plt.figure(figsize = (20,12))
dendrogram = sch.dendrogram(sch.linkage(df[FEATURES], method  = "ward"))
plt.title('Dendrogram')
plt.xlabel('Flowers')
plt.ylabel('Euclidean distances')
plt.show()

# %%
agg = AgglomerativeClustering(3, affinity = 'euclidean', linkage = 'single')
df['cluster_hierarquico'] = agg.fit_predict(df[FEATURES])
df.groupby('target')['cluster_hierarquico'].value_counts()
# Out:
# target  cluster_hierarquico
# 0       1                      50
# 1       0                      50
# 2       0                      48
#         2                       2
# Name: cluster_hierarquico, dtype: int64

# %%
plt.figure(figsize = (20,12))
dendrogram = sch.dendrogram(sch.linkage(df[FEATURES], method  = "single"))
plt.title('Dendrogram')
plt.xlabel('Flowers')
plt.ylabel('Euclidean distances')
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(16,8))
axes[0].scatter(df['sepal length (cm)'], df['petal length (cm)'], c=df['target'])
axes[1].scatter(df['sepal length (cm)'], df['petal length (cm)'], c=df['cluster_hierarquico'], cmap=plt.cm.Set1)
axes[0].set_title('Target', fontsize=18)
axes[1].set_title('Hierarchical', fontsize=18)
# Out:
# Text(0.5, 1.0, 'Hierarchical')

# %%
plt.figure(figsize = (20,12))
dendrogram = sch.dendrogram(sch.linkage(df[FEATURES], method  = "single"))
plt.title('Dendrogram')
plt.xlabel('Flowers')
plt.ylabel('Euclidean distances')
plt.show()

# %%
agg = AgglomerativeClustering(3, affinity = 'euclidean', linkage = 'complete')
df['cluster_hierarquico'] = agg.fit_predict(df[FEATURES])
df.groupby('target')['cluster_hierarquico'].value_counts()
# Out:
# target  cluster_hierarquico
# 0       1                      50
# 1       2                      27
#         0                      23
# 2       0                      49
#         2                       1
# Name: cluster_hierarquico, dtype: int64

# %%
fig, axes = plt.subplots(1, 2, figsize=(16,8))
axes[0].scatter(df['sepal length (cm)'], df['petal length (cm)'], c=df['target'])
axes[1].scatter(df['sepal length (cm)'], df['petal length (cm)'], c=df['cluster_hierarquico'], cmap=plt.cm.Set1)
axes[0].set_title('Target', fontsize=18)
axes[1].set_title('Hierarchical', fontsize=18)
# Out:
# Text(0.5, 1.0, 'Hierarchical')

# %%
plt.figure(figsize = (20,12))
dendrogram = sch.dendrogram(sch.linkage(df[FEATURES], method  = "complete"))
plt.title('Dendrogram')
plt.xlabel('Flowers')
plt.ylabel('Euclidean distances')
plt.show()

# %%
agg = AgglomerativeClustering(4, affinity = 'euclidean', linkage = 'complete')
df['cluster_hierarquico'] = agg.fit_predict(df[FEATURES])
df.groupby('target')['cluster_hierarquico'].value_counts()
# Out:
# target  cluster_hierarquico
# 0       0                      50
# 1       2                      27
#         1                      23
# 2       1                      37
#         3                      12
#         2                       1
# Name: cluster_hierarquico, dtype: int64

# %%
fig, axes = plt.subplots(1, 2, figsize=(16,8))
axes[0].scatter(df['sepal length (cm)'], df['petal length (cm)'], c=df['target'])
axes[1].scatter(df['sepal length (cm)'], df['petal length (cm)'], c=df['cluster_hierarquico'], cmap=plt.cm.Set1)
axes[0].set_title('Target', fontsize=18)
axes[1].set_title('Hierarchical', fontsize=18)
# Out:
# Text(0.5, 1.0, 'Hierarchical')

# %% [markdown]
# ### KMeans

# %%
from sklearn.cluster import KMeans

# %%
# fittando vários modelos e armazenando a inércia em uma lista
SSE = []
for cluster in range(1,20):
    kmeans = KMeans(n_clusters = cluster, init='k-means++')
    kmeans.fit(df[FEATURES])
    SSE.append(kmeans.inertia_)
# convertendo os resultados em um dataframe e plotando
frame = pd.DataFrame({'Cluster':range(1,20), 'SSE':SSE})
plt.figure(figsize=(12,6))
plt.plot(frame['Cluster'], frame['SSE'], marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
# Out:
# Text(0, 0.5, 'Inertia')

# %%
km = KMeans(3)

# %%
df['cluster_kmeans'] = km.fit_predict(df[FEATURES])

# %%
fig, axes = plt.subplots(1, 2, figsize=(16,8))
axes[0].scatter(df['sepal length (cm)'], df['petal length (cm)'], c=df['target'])
axes[1].scatter(df['sepal length (cm)'], df['petal length (cm)'], c=df['cluster_kmeans'], cmap=plt.cm.Set1)
axes[0].set_title('Target', fontsize=18)
axes[1].set_title('KMEANS', fontsize=18)
# Out:
# Text(0.5, 1.0, 'KMEANS')

# %% [markdown]
# ## DBScan

# %%
from sklearn.cluster import DBSCAN

# %%
db  = DBSCAN()

# %%
df['cluster_dbscan'] = db.fit_predict(df[FEATURES])

# %%
df['cluster_dbscan'].value_counts()
# Out:
#  1    84
#  0    49
# -1    17
# Name: cluster_dbscan, dtype: int64

# %%
fig, axes = plt.subplots(1, 2, figsize=(16,8))
axes[0].scatter(df['sepal length (cm)'], df['petal length (cm)'], c=df['target'])
axes[1].scatter(df['sepal length (cm)'], df['petal length (cm)'], c=df['cluster_dbscan'], cmap=plt.cm.Set1)
axes[0].set_title('Target', fontsize=18)
axes[1].set_title('DBSCAN', fontsize=18)
# Out:
# Text(0.5, 1.0, 'DBSCAN')

# %%
from sklearn.neighbors import NearestNeighbors

# %%
neighbors = NearestNeighbors(n_neighbors=8)
neighbors_fit = neighbors.fit(df[FEATURES])
distances, indices = neighbors_fit.kneighbors(df[FEATURES])

# %%
distances = np.sort(distances, axis=0)
plt.plot(distances[:,1])
plt.show()

# %%
db  = DBSCAN(eps= 0.4,  min_samples=8)
df['cluster_dbscan'] = db.fit_predict(df[FEATURES])
df['cluster_dbscan'].value_counts()
# Out:
# -1    66
#  0    45
#  1    21
#  2    10
#  3     8
# Name: cluster_dbscan, dtype: int64

# %%
fig, axes = plt.subplots(1, 2, figsize=(16,8))
axes[0].scatter(df['sepal length (cm)'], df['petal length (cm)'], c=df['target'])
axes[1].scatter(df['sepal length (cm)'], df['petal length (cm)'], c=df['cluster_dbscan'], cmap=plt.cm.Set1 )
axes[0].set_title('Target', fontsize=18)
axes[1].set_title('DBSCAN', fontsize=18)
# Out:
# Text(0.5, 1.0, 'DBSCAN')
